# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from surprise import Dataset, Reader
from surprise.model_selection import train_test_split
from surprise import KNNBasic
from surprise import accuracy
import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 13
#      11 from sklearn.feature_extraction.text import TfidfVectorizer
#      12 from sklearn.metrics.pairwise import linear_kernel
# ---> 13 from surprise import Dataset, Reader
#      14 from surprise.model_selection import train_test_split
#      15 from surprise import KNNBasic
#
# ModuleNotFoundError: No module named 'surprise'

# %%
df = pd.read_csv(r"Laptops.csv")

# %%
df.head()
# Out:
#    laptop_id                               full_name_with_specs  \
# 0          1  ASUS VivoBook S 15ProcessorAMD Ryzen 9 6900HXI...
# 1          2  HP OMEN 16ProcessorIntel Core i7-12700HInterna...
# 2          3  LG gram 17ProcessorIntel Core i7-1360PInternal...
# 3          4  HP 15ProcessorIntel Core i5-1135G7Internal mem...
# 4          5  HP ENVY 17ProcessorIntel Core i7-13700HInterna...
#
#                                         link_profile           full_name  \
# 0  https://laptopmedia.com/laptop-specs/asus-vivo...  ASUS VivoBook S 15
# 1  https://laptopmedia.com/laptop-specs/hp-omen-1...          HP OMEN 16
# 2  https://laptopmedia.com/laptop-specs/lg-gram-1...          LG gram 17
# 3  https://laptopmedia.com/laptop-specs/hp-15-17220/               HP 15
# 4  https://laptopmedia.com/laptop-specs/hp-envy-1...          HP ENVY 17
#
#   producer        model                   cpu  cpu_mark  \
# 0     ASUS  VivoBookS15    AMD Ryzen 9 6900HX     24906
# 1       HP       OMEN16  Intel Core i7-12700H     26457
# 2       LG       gram17   Intel Core i7-1360P     19277
# 3       HP           15  Intel Core i5-1135G7      9901
# 4       HP       ENVY17  Intel Core i7-13700H     28201
#
#                                    gpu                     disc  ...  \
# 0                      AMD Radeon 680M               2000GB SSD  ...
# 1  NVIDIA GeForce RTX 3050 Ti (Laptop)               1000GB SSD  ...
# 2     Intel Iris Xe Graphics G7 (96EU)               4000GB SSD  ...
# 3     Intel Iris Xe Graphics G7 (80EU)  2000GB SSD + 1000GB HDD  ...
# 4     NVIDIA GeForce RTX 3050 (Laptop)               1000GB SSD  ...
#
#   publishing_date price_in_dollar  \
# 0      25.09.2023             NaN
# 1      20.09.2023             NaN
# 2      20.09.2023             NaN
# 3      17.10.2023      $1,890.00
# 4      17.10.2023             NaN
#
#                                          review_link  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  https://laptopmedia.com/review/hp-15-15-dw1000...
# 4                                                NaN
#
#                                          amazon_link  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  https://www.amazon.com/exec/obidos/ASIN/B0CDRP...
# 4                                                NaN
#
#                                          dimensions              ethernet  \
# 0                                               NaN                   NaN
# 1  369.06 x 247.90 x 23 mm (14.53" x 9.76" x 0.91")  10, 100, 1000 Mbit/s
# 2                                               NaN                   NaN
# 3                                               NaN  10, 100, 1000 Mbit/s
# 4                                               NaN                   NaN
#
#    fingerprint_reader service_rank service_level           Purpose
# 0  Fingerprint reader          5.0        80/100  Gaming, coiding
# 1  Fingerprint reader          9.0        63/100               NaN
# 2  Fingerprint reader          NaN           NaN               NaN
# 3  Fingerprint reader          9.0        63/100               NaN
# 4                 NaN          9.0        63/100               NaN
#
# [5 rows x 32 columns]

# %%
df.describe()
# Out:
#          laptop_id      cpu_mark  service_rank
# count  1000.000000   1000.000000    960.000000
# mean    500.500000  17449.402000      5.985417
# std     288.819436  10213.614407      2.577636
# min       1.000000    589.000000      1.000000
# 25%     250.750000   9950.000000      3.000000
# 50%     500.500000  15836.500000      5.000000
# 75%     750.250000  23461.000000      9.000000
# max    1000.000000  56006.000000     10.000000

# %%
df.shape
# Out:
# (1000, 32)

# %%
df.isnull().sum()
# Out:
# laptop_id                 0
# full_name_with_specs      0
# link_profile              0
# full_name                 0
# producer                  0
# model                     0
# cpu                       0
# cpu_mark                  0
# gpu                       0
# disc                      0
# ram                       0
# ram_tech                838
# display_size              1
# display_resolution        1
# display_hz              619
# display_tech            329
# weight                  190
# hdmi_version            196
# wifi_version              8
# bluetooth_version        15
# webcam_resolution       126
# microphone_count        244
# publishing_date           0
# price_in_dollar         806
# review_link             806
# amazon_link             806
# dimensions              860
# ethernet                526
# fingerprint_reader      129
# service_rank             40
# service_level            40
# Purpose                 999
# dtype: int64
